# %% [markdown]
# **Step 5 - Train/Test Split**

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\HomePC\Crypto-BuySell-Classifier-Model\myenv\Scripts\python.exe

# %%
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix,classification_report

# %%
df=pd.read_csv(r"C:\Users\HomePC\Crypto-BuySell-Classifier-Model\notebooks\data\processed\BTCUSDT_1d_features.csv")
df.head()
# Out:
#        open_time      open      high  ...  stoch_rsi  stoch_rsi_d  stoch_rsi_k
# 0  1695168000000  27210.25  27388.63  ...   0.949032     0.980278     0.983011
# 1  1695254400000  27125.01  27159.60  ...   0.646835     0.943904     0.865289
# 2  1695340800000  26568.08  26743.38  ...   0.652932     0.865966     0.749600
# 3  1695427200000  26580.14  26632.81  ...   0.650666     0.755011     0.650144
# 4  1695513600000  26575.97  26738.54  ...   0.477119     0.664439     0.593572
#
# [5 rows x 26 columns]

# %%
# 70% train, 15% validation, 15% test

train_size = int(len(df) * 0.70)
val_size = int(len(df) * 0.85)

# Split the data
train = df.iloc[:train_size]
val = df.iloc[train_size:val_size]
test = df.iloc[val_size:]

# Or with features and target
X_train = df[feature_cols].iloc[:train_size]
X_val = df[feature_cols].iloc[train_size:val_size]
X_test = df[feature_cols].iloc[val_size:]

y_train = df[target_col].iloc[:train_size]
y_val = df[target_col].iloc[train_size:val_size]
y_test = df[target_col].iloc[val_size:]

# Corrected print statements
print(f"Train: {len(train)} samples ({len(train)/len(df)*100:.1f}%)")
print(f"Validation: {len(val)} samples ({len(val)/len(df)*100:.1f}%)")
print(f"Test: {len(test)} samples ({len(test)/len(df)*100:.1f}%)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 12
#       9 test = df.iloc[val_size:]
#      11 # Or with features and target
# ---> 12 X_train = df[feature_cols].iloc[:train_size]
#      13 X_val = df[feature_cols].iloc[train_size:val_size]
#      14 X_test = df[feature_cols].iloc[val_size:]
#
# NameError: name 'feature_cols' is not defined
